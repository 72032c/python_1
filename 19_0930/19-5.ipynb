# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(9),
                 index=[['a', 'a', 'a', 'b', 'b', 'c', 'c', 'd', 'd'],
                        [1, 2, 3, 1, 2, 3, 1, 2, 3]])
data
# Out:
# a  1   -0.557840
#    2    0.518902
#    3   -0.502764
# b  1   -1.031572
#    2   -0.363944
# c  3    0.780339
#    1   -0.947246
# d  2    1.531430
#    3   -0.556123
# dtype: float64

# %%
df1 = data.unstack()
df1
# Out:
#           1         2         3
# a -0.557840  0.518902 -0.502764
# b -1.031572 -0.363944       NaN
# c -0.947246       NaN  0.780339
# d       NaN  1.531430 -0.556123

# %%
df1.stack()
# Out:
# a  1   -0.557840
#    2    0.518902
#    3   -0.502764
# b  1   -1.031572
#    2   -0.363944
# c  1   -0.947246
#    3    0.780339
# d  2    1.531430
#    3   -0.556123
# dtype: float64

# %%
import numpy as np
import pandas as pd

frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
                    index=[['a','a','b','b'],[1, 2, 1, 2]],
                    columns=[['台北','台北','台中'],['Green','Red','Green']])
frame
# Out:
#        台北        台中
#     Green Red Green
# a 1     0   1     2
#   2     3   4     5
# b 1     6   7     8
#   2     9  10    11

# %%
frame.index.names = ['key1','key2']
frame.columns.names = ['縣市','顏色']
frame
# Out:
# 縣市           台北        台中
# 顏色        Green Red Green
# key1 key2
# a    1        0   1     2
#      2        3   4     5
# b    1        6   7     8
#      2        9  10    11

# %%
frame.stack(level='縣市')
# Out:
# /tmp/ipykernel_1355/2953987775.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   frame.stack(level='縣市')
# 顏色            Green   Red
# key1 key2 縣市
# a    1    台中      2   NaN
#           台北      0   1.0
#      2    台中      5   NaN
#           台北      3   4.0
# b    1    台中      8   NaN
#           台北      6   7.0
#      2    台中     11   NaN
#           台北      9  10.0

# %%
frame.stack(level=['縣市','顏色'])
# Out:
# /tmp/ipykernel_1355/3186678627.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   frame.stack(level=['縣市','顏色'])
# key1  key2  縣市  顏色
# a     1     台中  Green     2.0
#             台北  Green     0.0
#                 Red       1.0
#       2     台中  Green     5.0
#             台北  Green     3.0
#                 Red       4.0
# b     1     台中  Green     8.0
#             台北  Green     6.0
#                 Red       7.0
#       2     台中  Green    11.0
#             台北  Green     9.0
#                 Red      10.0
# dtype: float64
