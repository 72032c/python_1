# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50,5))
scores_pd = pd.DataFrame(scores,columns=['國文', '英文', '數學', '地理', '歷史'],index=range(1,51))
scores_pd.index.name="學號"
scores_pd.columns.name="科目"
scores_pd
# Out:
# 科目   國文  英文   數學   地理   歷史
# 學號
# 1    53  53   50   84   54
# 2    60  93   55   75   96
# 3    88  80   72   63   54
# 4    65  56   83   77   84
# 5    91  73  100   82   82
# 6    54  93   80   93   96
# 7    89  65   99   78   51
# 8    97  59   76   86   84
# 9    54  53  100   53   98
# 10  100  73   98   56   59
# 11   91  71   63   66   67
# 12   81  82   99   68   95
# 13   66  93   92   73   88
# 14   60  57   63   85   54
# 15   99  71   67   79   58
# 16   92  60   86  100   66
# 17   93  60   54   85   53
# 18   66  86   72   76   77
# 19   98  89   76   73   65
# 20   86  87   65   97   86
# 21   93  61   92   60   65
# 22   85  64   71   62   84
# 23   60  96   68   94   98
# 24   65  86   95   80   61
# 25   75  66   74   83   89
# 26   77  91   52   81   85
# 27   55  53   80   98   93
# 28   90  60   55   51   60
# 29   76  65   63   85   71
# 30   89  60   83   71   63
# 31   70  96   59   74   95
# 32   61  75   77   52   65
# 33   75  83   69   70   76
# 34   61  66   61   57   88
# 35   66  78   71   82   82
# 36   67  88   50   96   58
# 37   68  51   87   78   83
# 38   60  84   61   73   96
# 39   88  54   88   64   94
# 40   89  63  100   75   51
# 41   69  71   67   63   57
# 42   70  67   75   73   60
# 43   63  89   82   94   92
# 44   68  85   75   98   54
# 45   83  92   87   69   83
# 46   90  91   77  100  100
# 47   70  66   98   80   54
# 48   74  53   69  100   66
# 49   78  58   52   89   51
# 50   59  50   89   92   84

# %%
def call(s):
    min = s.min()
    max = s.max()
    median = s.median()
    return pd.Series([min,max,median],index=['最低分','最高分','中間值'])

scores_pd.apply(call)
# Out:
# 科目      國文    英文     數學     地理     歷史
# 最低分   53.0  50.0   50.0   51.0   51.0
# 最高分  100.0  96.0  100.0  100.0  100.0
# 中間值   74.5  71.0   75.0   78.0   76.5
