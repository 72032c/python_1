# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print("今天天氣很好",sep=';',end='.',file=sys.stdout)
#
# NameError: name 'sys' is not defined
