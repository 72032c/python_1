# %%
import requests
from requests import Response
from pprint import pprint
from pydantic import BaseModel, RootModel,Field

youbike_url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'

try:
    respons:Response = requests.request('GET',youbike_url)
    respons.raise_for_status()
except Exception:
    print("下載錯誤")
else:
    content = respons.text

class Station(BaseModel):
    站名:str=Field(alias="sna")
    行政區:str=Field(alias="sarea")
    日期:str=Field(alias="mday")
    地址:str=Field(alias="ar")
    狀態:str=Field(alias="act")
    總數:int=Field(alias="total")
    可借:int=Field(alias="availabel_rent_bikes")
    可還:int=Field(alias="availabel_return_bikes")

class Youbikes(RootModel):
    root:list[Station]

youbikes:Youbikes = Youbikes.model_validate_json(content)
youbikes_list = youbikes.model_dump()
pprint(youbikes_list)

for item in youbikes_list:
    pprint(item,indent=2)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[1], line 29
#      26 class Youbikes(RootModel):
#      27     root:list[Station]
# ---> 29 youbikes:Youbikes = Youbikes.model_validate_json(content)
#      30 youbikes_list = youbikes.model_dump()
#      31 pprint(youbikes_list)
#
# File ~/.local/lib/python3.11/site-packages/pydantic/main.py:597, in BaseModel.model_validate_json(cls, json_data, strict, context)
#     595 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     596 __tracebackhide__ = True
# --> 597 return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
#
# ValidationError: 2902 validation errors for Youbikes
# 0.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101001', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 0.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101001', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101002', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101002', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101003', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101003', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 3.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101004', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 3.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101004', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 4.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101005', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 4.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101005', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 5.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101006', 'sna...lable_return_bikes': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 5.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101006', 'sna...lable_return_bikes': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 6.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101007', 'sna...lable_return_bikes': 11}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 6.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101007', 'sna...lable_return_bikes': 11}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 7.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101008', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 7.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101008', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 8.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101009', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 8.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101009', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 9.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101010', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 9.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101010', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 10.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101012', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 10.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101012', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 11.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101013', 'sna...ilable_return_bikes': 8}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 11.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101013', 'sna...ilable_return_bikes': 8}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 12.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101014', 'sna...ilable_return_bikes': 3}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 12.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101014', 'sna...ilable_return_bikes': 3}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 13.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101015', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 13.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101015', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 14.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101016', 'sna...ilable_return_bikes': 2}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 14.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101016', 'sna...ilable_return_bikes': 2}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 15.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101018', 'sna...ilable_return_bikes': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 15.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101018', 'sna...ilable_return_bikes': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 16.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101019', 'sna...lable_return_bikes': 23}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 16.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101019', 'sna...lable_return_bikes': 23}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 17.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101020', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 17.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101020', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 18.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101021', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 18.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101021', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 19.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101022', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 19.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101022', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 20.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101023', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 20.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101023', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 21.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101024', 'sna...lable_return_bikes': 48}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 21.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101024', 'sna...lable_return_bikes': 48}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 22.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101025', 'sna...lable_return_bikes': 97}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 22.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101025', 'sna...lable_return_bikes': 97}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 23.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101026', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 23.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101026', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 24.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101027', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 24.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101027', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 25.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101028', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 25.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101028', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 26.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101029', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 26.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101029', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 27.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101030', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 27.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101030', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 28.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101031', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 28.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101031', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 29.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101032', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 29.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101032', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 30.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101033', 'sna...lable_return_bikes': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 30.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101033', 'sna...lable_return_bikes': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 31.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101034', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 31.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101034', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 32.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101035', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 32.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101035', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 33.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101036', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 33.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101036', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 34.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101037', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 34.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101037', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 35.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101038', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 35.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101038', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 36.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101039', 'sna...lable_return_bikes': 28}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 36.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101039', 'sna...lable_return_bikes': 28}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 37.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101040', 'sna...lable_return_bikes': 23}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 37.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101040', 'sna...lable_return_bikes': 23}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 38.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101041', 'sna...lable_return_bikes': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 38.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101041', 'sna...lable_return_bikes': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 39.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101042', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 39.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101042', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 40.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101091', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 40.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101091', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 41.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101092', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 41.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101092', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 42.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101093', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 42.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101093', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 43.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101094', 'sna...ilable_return_bikes': 8}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 43.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101094', 'sna...ilable_return_bikes': 8}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 44.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101095', 'sna...lable_return_bikes': 33}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 44.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101095', 'sna...lable_return_bikes': 33}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 45.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101097', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 45.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101097', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 46.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101098', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 46.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101098', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 47.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101099', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 47.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101099', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 48.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101100', 'sna...lable_return_bikes': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 48.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101100', 'sna...lable_return_bikes': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 49.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101101', 'sna...lable_return_bikes': 49}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 49.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101101', 'sna...lable_return_bikes': 49}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 50.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101102', 'sna...lable_return_bikes': 21}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 50.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101102', 'sna...lable_return_bikes': 21}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 51.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101103', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 51.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101103', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 52.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101104', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 52.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101104', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 53.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101105', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 53.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101105', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 54.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101107', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 54.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101107', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 55.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101108', 'sna...ilable_return_bikes': 3}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 55.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101108', 'sna...ilable_return_bikes': 3}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 56.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101109', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 56.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101109', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 57.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101110', 'sna...lable_return_bikes': 52}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 57.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101110', 'sna...lable_return_bikes': 52}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 58.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101111', 'sna...ilable_return_bikes': 8}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 58.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101111', 'sna...ilable_return_bikes': 8}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 59.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101113', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 59.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101113', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 60.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101114', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 60.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101114', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 61.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101115', 'sna...lable_return_bikes': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 61.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101115', 'sna...lable_return_bikes': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 62.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101116', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 62.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101116', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 63.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101117', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 63.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101117', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 64.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101118', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 64.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101118', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 65.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101119', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 65.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101119', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 66.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101120', 'sna...lable_return_bikes': 43}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 66.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101120', 'sna...lable_return_bikes': 43}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 67.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101122', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 67.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101122', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 68.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101123', 'sna...lable_return_bikes': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 68.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101123', 'sna...lable_return_bikes': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 69.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101124', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 69.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101124', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 70.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101125', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 70.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101125', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 71.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101126', 'sna...lable_return_bikes': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 71.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101126', 'sna...lable_return_bikes': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 72.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101127', 'sna...lable_return_bikes': 44}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 72.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101127', 'sna...lable_return_bikes': 44}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 73.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101128', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 73.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101128', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 74.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101129', 'sna...lable_return_bikes': 19}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 74.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101129', 'sna...lable_return_bikes': 19}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 75.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101130', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 75.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101130', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 76.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101131', 'sna...lable_return_bikes': 49}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 76.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101131', 'sna...lable_return_bikes': 49}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 77.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101132', 'sna...lable_return_bikes': 52}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 77.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101132', 'sna...lable_return_bikes': 52}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 78.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101133', 'sna...lable_return_bikes': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 78.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101133', 'sna...lable_return_bikes': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 79.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101134', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 79.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101134', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 80.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101135', 'sna...lable_return_bikes': 16}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 80.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101135', 'sna...lable_return_bikes': 16}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 81.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101136', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 81.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101136', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 82.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101137', 'sna...lable_return_bikes': 52}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 82.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101137', 'sna...lable_return_bikes': 52}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 83.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101138', 'sna...lable_return_bikes': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 83.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101138', 'sna...lable_return_bikes': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 84.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101139', 'sna...lable_return_bikes': 51}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 84.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101139', 'sna...lable_return_bikes': 51}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 85.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101140', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 85.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101140', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 86.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101141', 'sna...lable_return_bikes': 11}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 86.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101141', 'sna...lable_return_bikes': 11}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 87.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101142', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 87.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101142', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 88.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101143', 'sna...lable_return_bikes': 16}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 88.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101143', 'sna...lable_return_bikes': 16}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 89.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101144', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 89.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101144', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 90.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101145', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 90.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101145', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 91.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101146', 'sna...ilable_return_bikes': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 91.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101146', 'sna...ilable_return_bikes': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 92.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101147', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 92.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101147', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 93.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101148', 'sna...lable_return_bikes': 11}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 93.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101148', 'sna...lable_return_bikes': 11}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 94.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101149', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 94.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101149', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 95.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101150', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 95.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101150', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 96.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101151', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 96.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101151', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 97.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101152', 'sna...lable_return_bikes': 21}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 97.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101152', 'sna...lable_return_bikes': 21}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 98.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101153', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 98.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101153', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 99.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101154', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 99.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101154', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 100.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101155', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 100.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101155', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 101.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101156', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 101.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101156', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 102.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101157', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 102.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101157', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 103.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101158', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 103.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101158', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 104.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101159', 'sna...lable_return_bikes': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 104.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101159', 'sna...lable_return_bikes': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 105.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101160', 'sna...ilable_return_bikes': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 105.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101160', 'sna...ilable_return_bikes': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 106.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101161', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 106.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101161', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 107.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101162', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 107.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101162', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 108.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500101163', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 108.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500101163', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 109.availabel_rent_bikes
# ...
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1414.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119059', 'sna...lable_return_bikes': 68}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1415.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119060', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1415.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119060', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1416.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119061', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1416.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119061', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1417.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119062', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1417.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119062', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1418.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119063', 'sna...lable_return_bikes': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1418.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119063', 'sna...lable_return_bikes': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1419.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119064', 'sna...lable_return_bikes': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1419.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119064', 'sna...lable_return_bikes': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1420.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119065', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1420.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119065', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1421.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119066', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1421.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119066', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1422.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119067', 'sna...lable_return_bikes': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1422.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119067', 'sna...lable_return_bikes': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1423.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119068', 'sna...lable_return_bikes': 66}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1423.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119068', 'sna...lable_return_bikes': 66}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1424.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119069', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1424.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119069', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1425.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119070', 'sna...lable_return_bikes': 47}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1425.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119070', 'sna...lable_return_bikes': 47}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1426.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119071', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1426.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119071', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1427.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119072', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1427.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119072', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1428.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119074', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1428.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119074', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1429.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119075', 'sna...lable_return_bikes': 45}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1429.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119075', 'sna...lable_return_bikes': 45}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1430.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119076', 'sna...lable_return_bikes': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1430.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119076', 'sna...lable_return_bikes': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1431.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119077', 'sna...lable_return_bikes': 56}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1431.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119077', 'sna...lable_return_bikes': 56}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1432.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119078', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1432.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119078', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1433.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119079', 'sna...lable_return_bikes': 19}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1433.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119079', 'sna...lable_return_bikes': 19}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1434.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119080', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1434.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119080', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1435.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119081', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1435.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119081', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1436.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119082', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1436.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119082', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1437.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119083', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1437.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119083', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1438.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119084', 'sna...lable_return_bikes': 40}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1438.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119084', 'sna...lable_return_bikes': 40}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1439.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119085', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1439.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119085', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1440.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119086', 'sna...lable_return_bikes': 50}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1440.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119086', 'sna...lable_return_bikes': 50}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1441.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119087', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1441.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119087', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1442.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119088', 'sna...lable_return_bikes': 35}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1442.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119088', 'sna...lable_return_bikes': 35}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1443.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119089', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1443.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119089', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1444.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119090', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1444.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119090', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1445.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119091', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1445.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119091', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1446.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119092', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1446.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119092', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1447.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119093', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1447.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119093', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1448.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119094', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1448.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119094', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1449.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119095', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1449.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119095', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1450.availabel_rent_bikes
#   Field required [type=missing, input_value={'sno': '500119096', 'sna...lable_return_bikes': 89}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1450.availabel_return_bikes
#   Field required [type=missing, input_value={'sno': '500119096', 'sna...lable_return_bikes': 89}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
